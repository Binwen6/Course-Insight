# %%
# show me the basic opencv operations
import cv2
import numpy as np
import matplotlib.pyplot as plt

# read an image
img = cv2.imread('image/ML/1717246328094.png', cv2.IMREAD_COLOR)
# show the image
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-09-13 18:03:33.507 python[85690:10069946] _TIPropertyValueIsValid called with 11 on nil context!
# 2024-09-13 18:03:33.507 python[85690:10069946] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 11, bailing.
# 2024-09-13 18:03:33.507 python[85690:10069946] _TIPropertyValueIsValid called with 12 on nil context!
# 2024-09-13 18:03:33.507 python[85690:10069946] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 12, bailing.

# %%
# 进一步操作
# draw a line
cv2.line(img, (0, 0), (150, 150), (255, 255, 255), 15)
# draw a rectangle
cv2.rectangle(img, (15, 25), (200, 150), (0, 255, 0), 5)
# draw a circle
cv2.circle(img, (100, 63), 55, (0, 0, 255), -1)
# draw a polygon
pts = np.array([[10, 5], [20, 30], [70, 20], [50, 10]], np.int32)
# reshape the array to a 1x2 array
pts = pts.reshape((-1, 1, 2))
cv2.polylines(img, [pts], True, (0, 255, 255), 3)
# write some text
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, 'OpenCV Tuts!', (0, 130), font, 1, (200, 255, 255), 2, cv2.LINE_AA)
# show the image
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2024-09-13 18:04:39.427 python[85690:10069946] _TIPropertyValueIsValid called with 11 on nil context!
# 2024-09-13 18:04:39.427 python[85690:10069946] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 11, bailing.
# 2024-09-13 18:04:39.427 python[85690:10069946] _TIPropertyValueIsValid called with 12 on nil context!
# 2024-09-13 18:04:39.427 python[85690:10069946] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 12, bailing.
# 2024-09-13 18:04:39.480 python[85690:10069946] _TIPropertyValueIsValid called with 11 on nil context!
# 2024-09-13 18:04:39.480 python[85690:10069946] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 11, bailing.
# 2024-09-13 18:04:39.480 python[85690:10069946] _TIPropertyValueIsValid called with 12 on nil context!
# 2024-09-13 18:04:39.480 python[85690:10069946] imkxpc_setApplicationProperty:value:reply: called with incorrect property value 12, bailing.
